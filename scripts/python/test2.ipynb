# %%
import csv
reader = csv.reader(open("/Users/junfeng/Downloads/tmp.csv","r"))
plate_list = []
for plate_id,dummy,numCmpds in reader:
    if reader.line_num==1:
        continue
    plate_list.append([int(float(numCmpds)),plate_id])

# %%
plate_list = sorted(plate_list,reverse=True)
totalCmpds = 0
plateIds = []
for nCmpds,plate_id in plate_list:
    totalCmpds = totalCmpds + nCmpds
    plateIds.append(plate_id)
    if totalCmpds > 43318*0.9-11200:
        break

print(len(plateIds))
print(len(plate_list))
for plate_id in plateIds:
    print(plate_id)
# Out:
# 136
# 245
# SKHK_INT_271
# SKHK_INT_270
# SKHK_INT_267
# SKHK_INT_184
# SKHK_INT_255
# SKHK_INT_241
# SKHK_INT_235
# SKHK_INT_232
# SKHK_INT_226
# SKHK_INT_211
# SKHK_INT_243
# SKHK_INT_238
# SKHK_INT_259
# SKHK_INT_229
# SKHK_INT_215
# SKHK_INT_182
# SKHK_INT_099
# SKHK_INT_247
# SKHK_INT_248
# SKHK_INT_213
# SKHK_INT_190
# SKHK_INT_101
# SKHK_INT_269
# SKHK_INT_244
# SKHK_INT_179
# SKHK_INT_079
# SKHK_INT_240
# SKHK_INT_180
# SKHK_INT_181
# SKHK_INT_233
# SKHK_INT_279
# SKHK_INT_237
# SKHK_INT_212
# SKHK_INT_192
# SKHK_INT_258
# SKHK_INT_265
# SKHK_INT_275
# SKHK_INT_239
# SKHK_INT_191
# SKHK_INT_201
# SKHK_INT_105
# SKHK_INT_088
# SKHK_INT_102
# SKHK_INT_116
# SKHK_INT_083
# SKHK_INT_261
# SKHK_INT_214
# SKHK_INT_230
# SKHK_INT_216
# SKHK_INT_087
# SKHK_INT_078
# SKHK_INT_188
# SKHK_INT_081
# SKHK_INT_080
# SKHK_INT_219
# SKHK_INT_250
# SKHK_INT_203
# SKHK_INT_084
# SKHK_INT_200
# SKHK_INT_217
# SKHK_INT_114
# SKHK_INT_082
# SKHK_INT_086
# SKHK_INT_115
# SKHK_INT_117
# ...
